# %% [markdown]
# # Petya and Origami

# %% [markdown]
# https://codeforces.com/contest/1080/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, k = map(int, input().split())
red= ( ( 2 * n ) + k - 1 ) // k  
green= ( ( 5 * n ) + k - 1 ) // k  
blue= ( ( 8 * n ) + k - 1 ) // k  
sm=red+green+blue
print(sm)
# Out:
# 3 5
# 10
