# %% [markdown]
# # Snacktower

# %% [markdown]
# https://codeforces.com/problemset/problem/767/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
snacks = set()
for i in input().split():
    snacks.add(int(i))
    while n in snacks:
        print(n, end=' ')
        n -= 1
    print()
# Out:
# 5
# 4 5 1 2 3
#
# 5 4
#
#
# 3 2 1

# %%
n = int(input())
snacks = set()
for i in input().split():
    snacks.add(int(i))
    while n in snacks:
        print(n, end=' ')
        n -= 1
    print()
# Out:
# 3
# 3 1 2
# 3
#
# 2 1
