# %% [markdown]
# # Chef and digits of a number

# %% [markdown]
# https://www.codechef.com/problems/LONGSEQ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t=int(input())
for i in range(t):
        s=input()
        c1=s.count("1")
        c2=s.count("0")
        if(c1==1 or c2==1):
                print("Yes")
        else:
                print("No")
# Out:
# 2
# 101
# Yes
# 11
# No
