# %% [markdown]
# # Choose Two Numbers

# %% [markdown]
# https://codeforces.com/problemset/problem/1206/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
l=list(map(int,input().split()))
m=int(input())
p=list(map(int,input().split()))
for i in l:
    for j in p:
        k=i+j 
        if k in l:
            pass
        else:
            if k in p:
                pass
            else:
                print(i,j)
                exit(0)           #this code was working early
# Out:
# 1
# 20
# 2
# 20 10
# 20 20
# 20 10
