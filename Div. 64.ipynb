# %% [markdown]
# # Div. 64

# %% [markdown]
# https://codeforces.com/problemset/problem/887/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=input()
p=0
if '1' in n:
    m=n.index('1')
    for i in n[m+1:]:
        if i=='0':
            p+=1
    if p>=6:
        print("YES")
    else:
        print("NO")
else:
    print("NO")
# Out:
# 100
# NO
