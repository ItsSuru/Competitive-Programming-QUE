# %% [markdown]
# # Fake NP

# %% [markdown]
# https://codeforces.com/contest/805/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m=map(int,input().split())
if n== m:
    print(n)
else:
    print(2)
# Out:
# 19 29
# 2

# %%
n,m=map(int,input().split())
if n== m:
    print(n)
else:
    print(2)
# Out:
# 3 6
# 2

# %% [markdown]
# Multiple answers que
