# %% [markdown]
# # A pile of stones

# %% [markdown]
# https://codeforces.com/problemset/problem/1159/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
m=input()
k=0
ans=0
for i in range(n-1,-1,-1):
    if m[i]=='+':
        ans+=1
    else:
        ans-=1
    k=max(ans,k)
print(k)
# Out:
# 5
# ++-++
# 3
