# %% [markdown]
# # Eating Soup

# %% [markdown]
# https://codeforces.com/contest/1163/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m=map(int,input().split())
if m==0:
    print(1)
else:
    print(min(m,n-m))
# Out:
# 7 4
# 3

# %%
n,m=map(int,input().split())
if m==0:
    print(1)
else:
    print(min(m,n-m))
# Out:
# 6 2
# 2
