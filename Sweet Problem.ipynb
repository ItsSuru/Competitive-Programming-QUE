# %% [markdown]
# # Sweet Problem

# %% [markdown]
# https://codeforces.com/problemset/problem/1263/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t=int(input())
for i in range(t):
    r,g,b=sorted(list(map(int,input().split())))
    print(min((r+g),(r+g+b)//2))
# Out:
# 6
# 1 1 1
# 1
# 1 2 1
# 2
# 4 1 1
# 2
# 7 4 10
# 10
# 8 1 4
# 5
# 8 2 8
# 9
