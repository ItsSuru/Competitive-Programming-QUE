# %% [markdown]
# # Between the Offices

# %% [markdown]
# https://codeforces.com/problemset/problem/867/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
a = input()[:n]
a = a.upper()
if a[0]=="F":
    print("NO")
else:
    if a[0]==a[-1]:
        print("NO")
    else:
        print("YES")
# Out:
# 10
# ssffsffsff
# YES
