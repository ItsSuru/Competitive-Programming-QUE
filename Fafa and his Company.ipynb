# %% [markdown]
# # Fafa and his Company

# %% [markdown]
# https://codeforces.com/problemset/problem/935/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
j=0
i=1
while i<n:
    if n%i==0:
        j+=1
    i+=1    
print(j)
# Out:
# 10
# 3
