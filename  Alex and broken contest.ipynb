# %% [markdown]
# #  Alex and broken contest

# %% [markdown]
# https://codeforces.com/problemset/problem/877/A

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
n=input()
k=["Danil", "Olya", "Slava", "Ann", "Nikita"]
p=0
o=0
for i in k:
    if n.count(i) == 1:
        p+=1
    if n.count(i) > 1:
        o+=1
if p==1 and o==0:
    print("YES")
else:
    print("NO")
# Out:
# NikitaAndString
# YES
