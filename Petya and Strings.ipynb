# %% [markdown]
# # Petya and Strings

# %% [markdown]
# https://codeforces.com/contest/112/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=input()
b=input()
c=a.upper()
d=b.upper()
if c>d:
    print("1")
elif c<d:
    print("-1")
else:
    print("0")
# Out:
# abcdefg
# AbCdEfF
# 1
