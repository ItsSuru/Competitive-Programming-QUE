# %% [markdown]
# # Row

# %% [markdown]
# https://codeforces.com/problemset/problem/982/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
m='0'+input()+'0'
if '000' in m or '11' in m:
    print('NO')
else:
    print('YES')
# Out:
# 5
# 10001
# NO

# %%
n=int(input())
m='0'+input()+'0'
if '000' in m or '11' in m:
    print('NO')
else:
    print('YES')
# Out:
# 3
# 101
# YES
