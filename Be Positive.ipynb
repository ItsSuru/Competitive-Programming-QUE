# %% [markdown]
# # Be Positive

# %% [markdown]
# https://codeforces.com/contest/1130/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
l=list(map(int,input().split()))
c=0
c1=0
for i in l:
     if i>0:
          c+=1
     elif i<0:
          c1+=1
if c>=(n+1)//2:
     print("1")
elif c1>=(n+1)//2:
     print("-1")
else:
     print("0")
# Out:
# 5
# 10 0 -7 2 6
# 1
