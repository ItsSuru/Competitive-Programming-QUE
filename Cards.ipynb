# %% [markdown]
# # Cards

# %% [markdown]
# https://codeforces.com/problemset/problem/1220/A

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
inp = int(input())
a = input()
n = a.count("n")
z = a.count("z")
for i in range(n):
    print("1 ",end="")
for j in range(z):
    print("0")
# Out:
# 4
# ezor
# 0
