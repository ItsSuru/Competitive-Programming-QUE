# %% [markdown]
# # Little C Loves 3 I

# %% [markdown]
# https://codeforces.com/problemset/problem/1047/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=int(input())
m=1
k=1
p=n-2
if p%3==0:
    p-=1
    k+=1
print(m,k,p)
# Out:
# 233
# 1 2 230

# %%
n=int(input())
m=1
k=1
p=n-2
if p%3==0:
    p-=1
    k+=1
print(m,k,p)
# Out:
# 3
# 1 1 1
