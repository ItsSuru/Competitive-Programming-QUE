# %% [markdown]
# # Coins

# %% [markdown]
# https://codeforces.com/contest/1061/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m=map(int,input().split())
k=m//n
if n*k==m:
    print(k)
elif n*k<m:
    print(k+1)
# Out:
# 5 11
# 3

# %%
n,m=map(int,input().split())
k=m//n
if n*k==m:
    print(k)
elif n*k<m:
    print(k+1)
# Out:
# 6 16
# 3
