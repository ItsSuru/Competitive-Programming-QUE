# %% [markdown]
# # Watermelon

# %% [markdown]
# https://codeforces.com/contest/4/problem/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = int(input())
if i%2==0 and i!=2:
    print("YES")
else:
    print("NO")
# Out:
# 9
# NO
