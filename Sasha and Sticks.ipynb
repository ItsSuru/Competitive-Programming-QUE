# %% [markdown]
# # Sasha and Sticks

# %% [markdown]
# https://codeforces.com/problemset/problem/832/A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,m=map(int,input().split())
k=n//m
if k%2==0:
    print("NO")
else:
    print("YES")
# Out:
# 10 4
# NO
